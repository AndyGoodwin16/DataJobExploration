# %%
import pandas as pd

# %%
file = "salary_data_cleaned.csv"
file2 = "advisorsmith_cost_of_living_index.csv"

df = pd.read_csv(file)
df2 = pd.read_csv(file2)
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 737           Sr Scientist, Immuno-Oncology - Oncology
# 738                               Senior Data Engineer
# 739  Project Scientist - Auton Lab, Robotics Institute
# 740                               Data Science Manager
# 741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 737  $58K-$111K (Glassdoor est.)
# ...

# %%
df3 = df[["Job Title", "Salary Estimate", "Rating", "Company Name", "Location", "Size", "Founded", "Type of ownership", "Sector", "Revenue"]]
df3
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 737           Sr Scientist, Immuno-Oncology - Oncology
# 738                               Senior Data Engineer
# 739  Project Scientist - Auton Lab, Robotics Institute
# 740                               Data Science Manager
# 741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  Rating  \
# 0     $53K-$91K (Glassdoor est.)     3.8
# 1    $63K-$112K (Glassdoor est.)     3.4
# 2     $80K-$90K (Glassdoor est.)     4.8
# 3     $56K-$97K (Glassdoor est.)     3.8
# 4    $86K-$143K (Glassdoor est.)     2.9
# ..                           ...     ...
# ...

# %%
df4[["Job Title", "Salary Estimate", "Rating", "Company Name", "Location", "Size", "Founded", "Type of ownership", "Sector", "Revenue"]] = df3["Company Name"].str.split('\n', 1, expand=True)
df3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21432/1235159194.py in <module>
# ----> 1 df4[["Job Title", "Salary Estimate", "Rating", "Company Name", "Location", "Size", "Founded", "Type of ownership", "Sector", "Revenue"]] = df3["Company Name"].str.split('\n', 1, expand=True)
#       2 df3
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3598             self._setitem_frame(key, value)
#    3599         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
#    3602             self._set_item_frame_value(key, value)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3637         else:
#    3638             if isinstance(value, DataFrame):
# ...

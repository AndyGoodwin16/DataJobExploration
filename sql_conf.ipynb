# %%
import numpy as np

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

from flask import Flask, jsonify, render_template
import pandas as pd

# %%
engine = create_engine("sqlite:///data_jobs_db.sqlite")

# %%
conn = engine.connect()

# %%
# reflect an existing database into a new model
Base = automap_base()

# %%
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
df = pd.read_csv('data/working_table.csv')

# %%
df = df.loc[:,'job_title':]

# %%
df.to_sql('jobs',con=engine,if_exists='replace',index=True)

# %%
sql_df = pd.read_sql_table('jobs',con=engine)
sql_df
# Out:
#      index                                          job_title  low_end_salary  \
# 0        0                                     Data Scientist           53000
# 1        1                          Healthcare Data Scientist           63000
# 2        2                                     Data Scientist           80000
# 3        3                                     Data Scientist           56000
# 4        4                                     Data Scientist           86000
# ..     ...                                                ...             ...
# 702    702           Sr Scientist, Immuno-Oncology - Oncology           58000
# 703    703                               Senior Data Engineer           72000
# 704    704  Project Scientist - Auton Lab, Robotics Institute           56000
# 705    705                               Data Science Manager           95000
# 706    706          Research Scientist – Security and Privacy           61000
#
#      middle_range_salary  high_end_salary  \
# 0                  72000            91000
# 1                  87500           112000
# 2                  85000            90000
# 3                  76500            97000
# 4                 114500           143000
# ..                   ...              ...
# 702                84500           111000
# 703               102500           133000
# 704                73500            91000
# 705               127500           160000
# 706                93500           126000
#
#                               company_name     job_location  \
# 0                        Tecolote Research  Albuquerque, NM
# 1    University of Maryland Medical System    Linthicum, MD
# 2                                  KnowBe4   Clearwater, FL
# 3                                     PNNL     Richland, WA
# 4                       Affinity Solutions     New York, NY
# ..                                     ...              ...
# 702                                    GSK    Cambridge, MA
# 703                             Eventbrite    Nashville, TN
# 704         Software Engineering Institute   Pittsburgh, PA
# 705                           Numeric, LLC    Allentown, PA
# 706           Riverside Research Institute  Beavercreek, OH
#
#                            sector       type_of_ownership  \
# 0             Aerospace & Defense       Company - Private
# 1                     Health Care      Other Organization
# 2               Business Services       Company - Private
# 3    Oil, Gas, Energy & Utilities              Government
# 4               Business Services       Company - Private
# ..                            ...                     ...
# 702     Biotech & Pharmaceuticals        Company - Public
# 703        Information Technology        Company - Public
# 704                     Education    College / University
# 705             Business Services       Company - Private
# 706                    Government  Nonprofit Organization
#
#             size_of_company  rating_of_company  cost_of_living_index  \
# 0     501 to 1000 employees                3.8                  92.9
# 1          10000+ employees                3.4                   NaN
# 2     501 to 1000 employees                4.8                   NaN
# 3    1001 to 5000 employees                3.8                   NaN
# 4       51 to 200 employees                2.9                 128.0
# ..                      ...                ...                   ...
# 702        10000+ employees                3.9                   NaN
# 703  1001 to 5000 employees                4.4                 100.1
# 704   501 to 1000 employees                2.6                  93.1
# 705       1 to 50 employees                3.2                  98.9
# 706   501 to 1000 employees                3.6                   NaN
#
#      avg_salary_index  salary_col_differential        lat         lng state
# 0                70.1                  36402.0  35.084386 -106.650422    NM
# 1                85.2                      NaN  39.205108  -76.652746    MD
# 2                82.8                      NaN  27.965853  -82.800103    FL
# 3                74.5                      NaN  46.280420 -119.275200    WA
# 4               111.6                  65566.0  40.712775  -74.005973    NY
# ..                ...                      ...        ...         ...   ...
# 702              82.3                      NaN  42.373616  -71.109733    MA
# 703              99.9                  64233.0  36.162664  -86.781602    TN
# 704              71.6                  37865.0  40.440625  -79.995886    PA
# 705             124.2                  89634.0  40.602294  -75.471410    PA
# 706              91.1                      NaN  39.709226  -84.063268    OH
#
# [707 rows x 17 columns]

# %%
df2 = pd.read_csv('data/working_table2.csv')

# %%
df2.head()
# Out:
#   state  middle_range_salary  cost_of_living_index  salary_col_differential
# 0    AL         57937.500000             91.214286             25682.857143
# 1    AZ         85666.666667            104.300000             45160.000000
# 2    CA        122493.243243            170.268056             65912.222222
# 3    CO         94125.000000            112.100000             55022.200000
# 4    CT         71100.000000            104.800000             22405.000000

# %%
df2.to_sql('states',con=engine,if_exists='replace',index=True)

# %%
df2_test = pd.read_sql_table('states',con=engine)
df2_test
# Out:
#     index state  middle_range_salary  cost_of_living_index  \
# 0       0    AL         57937.500000             91.214286
# 1       1    AZ         85666.666667            104.300000
# 2       2    CA        122493.243243            170.268056
# 3       3    CO         94125.000000            112.100000
# 4       4    CT         71100.000000            104.800000
# 5       5    DC        110181.818182            120.100000
# 6       6    FL         77625.000000            102.850000
# 7       7    GA         80666.666667            100.300000
# 8       8    IA         78900.000000             89.900000
# 9       9    IL        116662.500000             99.017143
# 10     10    IN         90300.000000             90.200000
# 11     11    KY         97000.000000             88.266667
# 12     12    LA         63000.000000             90.533333
# 13     13    MA        108483.695652            125.706061
# 14     14    MD         97357.142857            107.000000
# 15     15    MI        100250.000000             95.233333
# 16     16    MN         85500.000000            105.400000
# 17     17    MO         84722.222222             88.920000
# 18     18    NC         98452.380952             95.157143
# 19     19    NE         57000.000000             92.900000
# 20     20    NM         74333.333333             92.900000
# 21     21    NY         98485.915493            122.898462
# 22     22    OH         87571.428571             91.733333
# 23     23    OR         92125.000000            113.550000
# 24     24    PA         97209.677419             96.390000
# 25     25    RI        100000.000000            111.500000
# 26     26    SC         60500.000000             91.900000
# 27     27    TN        100500.000000             94.737500
# 28     28    TX        100708.333333            100.242857
# 29     29    UT         94150.000000            104.371429
# 30     30    VA         95621.951220             99.433333
# 31     31    WA         93190.476190            122.316667
# 32     32    WI         73300.000000             94.050000
#
#     salary_col_differential
# 0              25682.857143
# 1              45160.000000
# 2              65912.222222
# 3              55022.200000
# 4              22405.000000
# 5              64222.000000
# 6              50145.500000
# 7              42978.333333
# 8              44837.000000
# 9              84307.457143
# 10             56868.000000
# 11             63184.666667
# 12             28377.333333
# 13             51629.212121
# 14             28714.000000
# 15             70885.666667
# 16             45166.500000
# 17             26675.400000
# 18             62033.666667
# 19             21416.000000
# 20             38796.666667
# 21             51825.123077
# 22             64047.666667
# 23             41278.500000
# 24             65955.800000
# 25             57305.000000
# 26             25289.000000
# 27             62705.750000
# 28             59457.000000
# 29             51557.714286
# 30             63599.000000
# 31             43603.000000
# 32             37306.100000
